# %% [markdown]
# # 인공지능응용 · Week 04 · 변경 이력을 남기며 협업하기
#
# **본인 사본을 만들어 실행·수정·기록하세요.**
#
# - 이름: **⟦여기에 직접 입력⟧**
# - 학번: **⟦여기에 직접 입력⟧**
#
# [자습 자료](https://chorok-daddy.github.io/courses/ai-applications/git-collaboration/index.html) · [실습 안내](https://chorok-daddy.github.io/courses/ai-applications/git-collaboration/assignment.html)
#
# ## 시작 전 · 셀 실행과 작성 방법
# Code Cell 왼쪽 ▶ 또는 Shift+Enter로 실행하세요. 위에서부터 진행하며 앞 셀의 변수를 사용합니다. Text Cell은 더블클릭해 **⟦직접 입력⟧** 부분을 바꾸고 Shift+Enter로 표시합니다. 기준 예제는 실행해서 이해하고, **직접 작성** 셀에 본인 코드를 작성하세요. 값을 바꾸면 해당 셀과 뒤의 관련 셀을 다시 실행합니다.
#
# **60분 진행:** 예상한 결과를 기록하고 실행한 뒤, 조건을 바꾸어 비교하세요. 마지막에는 새 세션에서 다시 실행하고 작성한 설명과 파일을 확인하세요. 시간이 남으면 마지막 선택 실습을 수행하세요.
#
# Colab에 필요한 라이브러리가 없으면 새 런타임에서 환경을 확인하고 조교에게 문의하세요. CPU로 기준 실습을 실행할 수 있습니다. 외부 다운로드가 필요한 실습은 해당 셀에 표시합니다.

# %% [markdown]
# ## 1. 내 작업 공간에서 Git 연습하기
#
# 임시 폴더에서 commit과 branch만 연습합니다. 실제 협업 과제는 과제 안내에서 이어갑니다.
#
# ### A. 기준 예제 · 먼저 읽고 실행

# %%
import tempfile, pathlib, subprocess
repo=pathlib.Path(tempfile.mkdtemp(prefix='course-git-'))
def git(*args):
    return subprocess.check_output(['git','-C',str(repo),*args],text=True,stderr=subprocess.STDOUT)
git('init','-b','main');git('config','user.name','Student Example');git('config','user.email','example@example.invalid')
(repo/'README.md').write_text('# Practice\nBaseline\n')
git('add','README.md');git('commit','-m','Add baseline')
git('switch','-c','practice-change')
(repo/'README.md').write_text('# Practice\nBaseline\nMy change\n')
print(git('diff'));git('add','README.md');git('commit','-m','Describe one change')
print(git('log','--oneline','--all','--graph'))

# %% [markdown]
# ### B. 직접 수행
#
# ① 로컬 예제의 문장을 한 줄 수정하고 git diff→add→commit→log를 직접 반복하세요. ② GitHub에서 README를 포함한 개인 연습 Repository를 만드세요. ③ 새 Branch practice를 만들고 README에 이번 주 배운 내용을 추가하여 Commit하세요. ④ practice→main의 Pull Request를 열고 Files changed에서 변경을 검토한 뒤 Merge하세요. ⑤ 조교 또는 동료에게 두 Branch의 역할과 Merge 전후 차이를 설명하세요. ⑥ Repository URL, Commit 이력, PR 변경 내용과 Merge 완료 화면을 Notebook에 기록하세요. 40분 안에 마치면 선택: 동료의 연습 Repository를 Fork하고 한 줄 수정하여 원본으로 PR을 제안해 Collaborator 방식과 비교하세요.
#
# 예상은 정확한 수치 대신 shape나 증가·감소 방향으로 적어도 됩니다. 코드는 위 예제를 참고해 작성하고, 설명만 묻는 항목은 아래 Text Cell에 답하세요.

# %%
# ✍ 직접 작성: 이 셀 아래에 본인의 코드를 추가하세요.
# 코드가 길어지면 Code Cell을 추가해도 됩니다.

# %% [markdown]
# ### C. 직접 기록 · 이 Text Cell을 더블클릭해서 수정
#
# - 확인하거나 바꾼 조건: **⟦직접 입력⟧**
# - 실행 전 예상: **⟦직접 입력⟧**
# - Commit·PR·Merge에서 확인한 내용: **⟦직접 입력⟧**
# - 예상과 차이 및 설명: **⟦직접 입력⟧**

# %% [markdown]
# ## 변경 이력 정리
#
# 앞에서 수행한 파일 수정·Commit·PR·Merge를 다시 보고 아래 내용을 정리하세요. 별도 Repository나 PR을 세 개 더 만들 필요는 없습니다.
#
# | 단계 | 확인할 것 | 내 기록 |
# |---|---|---|
# | 수정·Commit | 무엇을 바꾸었고 어떤 메시지로 기록했나요? | ⟦직접 입력⟧ |
# | PR | 변경 출발 Branch와 합칠 대상 Branch는 무엇인가요? | ⟦직접 입력⟧ |
# | Merge | main에 반영된 내용과 Commit 이력은 어디서 보이나요? | ⟦직접 입력⟧ |

# %%
# ✍ 반복 실험 코드

# %% [markdown]
# ## 선택 실습 · PR 변경 내용 읽기
#
# 시간이 남으면 연습 Repository의 README 한 줄을 바꾸는 PR을 하나 더 만들고, Merge 전에 변경 내용을 설명하세요.
#
# ## 저장 전 확인
#
# 1. 직접 작성란을 채우고 필요한 출력·그래프를 남겼는지 확인합니다.
# 2. 새 런타임에서 위에서부터 실행해 숨은 변수 의존성을 확인합니다.
# 3. 수정한 파일을 본인 Drive에 저장하고 `.ipynb`로 내려받습니다.
# 4. 제출 파일명·기한은 블로그의 이번 주 실습 안내와 최신 KLAS 공지를 따릅니다.
