# %% [markdown]
# # 인공지능응용 2주차 실습
#
# **AI 주제를 설명하는 나의 Notebook**
#
# 1. 본인 Google Drive에 사본을 저장하고 파일명을 **이름_학번_2주차.ipynb**로 바꿉니다.
# 2. **「읽기 안내」는 설명**, **「✍ 직접 작성」은 본인이 수정할 셀**입니다.
# 3. 작성 셀을 **두 번 클릭**하면 편집할 수 있습니다. `⟪…⟫`로 표시한 부분을 **괄호까지 지우고 자신의 내용으로 교체**하세요.
# 4. 입력 후 **Shift+Enter**를 눌러 표시 결과를 확인합니다. 표의 `|`, 목록의 `-`·`1.`, 강조의 `**` 같은 Markdown 기호는 유지하세요.
#
# 예: `이름: ⟪본인 이름⟫` → `이름: 홍길동`
#
# 이미지·수식·링크도 지정된 작성 위치의 `⟪…⟫` 전체를 실제 Markdown/LaTeX로 바꿉니다. 입력 안내를 답안으로 남겨두지 마세요. 「Markdown 오류 수정」에서는 다음 문제 셀의 잘못된 문법을 직접 고칩니다.
#
# **환경:** Python 기본 런타임. GPU·개인 Drive 마운트·추가 설치가 필요하지 않습니다.
#
# [과제 안내](https://chorok-daddy.github.io/courses/ai-applications/notebook-literacy/assignment.html)
#
# 자료 버전: 2026-2-03 · 과제 마감: 2026-09-10 23:59 (변경 시 KLAS 안내 우선)

# %% [markdown]
# ## 0. 코드 실행 확인
#
# 아래 코드 셀의 실행 버튼 또는 Shift+Enter를 누르세요. 평균이 22.0으로 나오는지 확인합니다. 이 셀은 문장을 입력하는 작성란이 아닙니다.

# %%
readings = [20, 22, 24]
average = sum(readings) / len(readings)
print("평균:", average)

# %% [markdown]
# ### 읽기 안내 · 주제와 작성자
#
# 자신의 AI 주제를 제목에 적고 이름·학번을 입력합니다. 제목 앞의 `#`는 유지하세요.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 주제와 작성자**
#
# # ⟪내가 선택한 AI 주제⟫
#
# 이름: ⟪본인 이름⟫
# 학번: ⟪본인 학번⟫

# %% [markdown]
# ### 읽기 안내 · 기술 소개
#
# 선택한 기술을 **3–5문장**으로 소개하세요. 무엇을 하는 기술인지, 어떤 데이터를 사용하는지, 해결할 문제와 실제 활용을 포함합니다. 아래 제목 구조는 유지하거나 자신의 주제에 맞게 바꿀 수 있습니다.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 기술 소개**
#
# ## 1. 기술 소개
#
# ### 어떤 문제를 해결하는가?
#
# ⟪여기를 지우고 기술·데이터·해결 문제·활용을 소개하는 3–5문장을 입력하세요⟫

# %% [markdown]
# ### 읽기 안내 · 핵심 용어와 특징
#
# 굵게·기울임·인라인 코드를 각각 본인 내용에 적용합니다. 아래 예시 틀의 기호는 남기고 안의 입력 표시만 교체하세요. 이어서 특징을 글머리 목록 3개 이상으로 적습니다.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 핵심 용어와 특징**
#
# ## 2. 핵심 용어와 특징
#
# **⟪핵심 용어⟫**: ⟪이 용어의 의미⟫
#
# *⟪이 기술에서 강조할 특징⟫*
#
# `⟪관련 함수·변수 또는 코드 표현⟫`: ⟪이 표현의 의미⟫
#
# - ⟪특징 1⟫
# - ⟪특징 2⟫
# - ⟪특징 3⟫

# %% [markdown]
# ### 읽기 안내 · AI 처리 과정
#
# 입력부터 결과까지 본인 주제의 처리 과정을 순서 목록 **4단계 이상**으로 적습니다. 아래 `1.`부터 `4.`까지 번호 뒤의 입력 표시를 교체하세요.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · AI 처리 과정**
#
# ## 3. AI 처리 과정
#
# 1. ⟪첫 단계에서 하는 일⟫
# 2. ⟪두 번째 단계에서 하는 일⟫
# 3. ⟪세 번째 단계에서 하는 일⟫
# 4. ⟪네 번째 단계에서 하는 일⟫

# %% [markdown]
# ### 읽기 안내 · 관련 이미지
#
# 이미지 **1개 이상**과 설명 **1–2문장**을 넣습니다. 다음 문법을 작성 셀의 이미지 위치에 입력하고 실제 주소로 바꾸세요. 코드 블록의 백틱 세 개는 옮기지 않습니다.
#
# ```markdown
# ![그림이 보여주는 내용](이미지의 실제 주소)
# ```
#
# Shift+Enter 후 이미지가 실제로 보이는지 확인하세요. 개인에게만 보이는 주소는 피하고 다른 사람도 볼 수 있는지 확인합니다.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 관련 이미지**
#
# ## 4. 관련 이미지
#
# ⟪이 줄 전체를 이미지 Markdown으로 교체하세요⟫
#
# 그림 설명: ⟪그림이 보여주는 내용과 AI 주제와의 관계를 1–2문장으로 입력하세요⟫

# %% [markdown]
# ### 읽기 안내 · 비교 표
#
# 열 제목을 본인의 비교 기준으로 바꾸고 **3열 이상, 데이터 행 4개 이상**을 채웁니다. `|`와 헤더 아래의 `---`는 유지합니다. 헤더는 데이터 행 수에 포함하지 않습니다.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 비교 표**
#
# ## 5. 비교 표
#
# | ⟪비교 기준 A⟫ | ⟪비교 기준 B⟫ | ⟪비교 기준 C⟫ |
# |---|---|---|
# | ⟪1행 A⟫ | ⟪1행 B⟫ | ⟪1행 C⟫ |
# | ⟪2행 A⟫ | ⟪2행 B⟫ | ⟪2행 C⟫ |
# | ⟪3행 A⟫ | ⟪3행 B⟫ | ⟪3행 C⟫ |
# | ⟪4행 A⟫ | ⟪4행 B⟫ | ⟪4행 C⟫ |

# %% [markdown]
# ### 읽기 안내 · 수식과 의미
#
# LaTeX 수식 **2개 이상**과 각각의 의미 설명 **1문장 이상**을 적습니다. 각 수식 위치의 입력 표시 전체를 `$$`로 감싼 수식으로 교체하세요.
#
# ```text
# $$
# 이 줄에 LaTeX 식을 입력
# $$
# ```
#
# 위 예시의 설명 문장 대신 실제 식을 적고, 코드 블록의 백틱은 옮기지 않습니다. Shift+Enter 후 수식이 표시되는지 확인하세요.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 수식과 의미**
#
# ## 6. 수식과 의미
#
# ### 수식 1
#
# ⟪이 줄 전체를 $$로 감싼 첫 번째 LaTeX 수식으로 교체하세요⟫
#
# 수식 1의 의미: ⟪기호와 수식의 의미를 1문장 이상 입력하세요⟫
#
# ### 수식 2
#
# ⟪이 줄 전체를 $$로 감싼 두 번째 LaTeX 수식으로 교체하세요⟫
#
# 수식 2의 의미: ⟪기호와 수식의 의미를 1문장 이상 입력하세요⟫

# %% [markdown]
# ### 읽기 안내 · 참고자료
#
# 본인의 AI 주제와 관련된 링크 **1개 이상**과 선택 이유 또는 내용 설명 **1–2문장**을 적습니다.
#
# ```markdown
# [자료 이름](자료의 실제 주소)
# ```
#
# 다음 작성 셀에 이 문법을 입력하고 실제 이름·주소로 바꿉니다.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · 참고자료**
#
# ## 7. 참고자료
#
# ⟪이 줄 전체를 실제 자료의 Markdown 링크로 교체하세요⟫
#
# 선택 이유 또는 자료 내용: ⟪1–2문장으로 입력하세요⟫

# %% [markdown]
# ## 8. 지정 코드 실행
#
# 다음은 과제에 지정된 코드입니다. 그대로 실행해 `Number of AI fields: 4`를 확인합니다. 답변은 코드 안에 쓰지 않고 **그 다음 「✍ 직접 작성」 텍스트 셀**에 적습니다.

# %%
ai_fields = [
    "Computer Vision",
    "Natural Language Processing",
    "Robotics",
    "Generative AI"
]
print("Number of AI fields:", len(ai_fields))

# %% [markdown]
# ### 읽기 안내 · Markdown Cell과 Code Cell의 차이
#
# 앞의 코드를 실행한 뒤 다음 두 질문에 답합니다. Q1은 실행 위치의 이유, Q2는 두 셀의 차이 **2가지 이상**입니다.
#
# **바로 다음의 「✍ 직접 작성」 셀을 두 번 클릭해 입력하세요.**

# %% [markdown]
# > **✍ 직접 작성 · Markdown Cell과 Code Cell의 차이**
#
# ### Markdown Cell과 Code Cell의 차이
#
# **Q1. 위 코드를 Code Cell에서 실행해야 하는 이유는 무엇인가요?**
#
# ⟪본인의 답변을 입력하세요⟫
#
# **Q2. 두 셀의 차이를 2가지 이상 적으세요.**
#
# 1. ⟪첫 번째 차이⟫
# 2. ⟪두 번째 차이⟫

# %% [markdown]
# ## 9. Markdown 오류 수정
#
# **바로 다음 셀 전체가 직접 수정할 문제입니다.** 일부러 잘못 작성된 제목·강조·번호 목록·표 문법을 고칩니다. 이 문제에는 `⟪…⟫` 입력 표시가 없습니다.
#
# 다음 셀을 두 번 클릭해 기존 문법을 수정하고 Shift+Enter로 결과를 확인하세요. 자신의 보고서에 만드는 3열·4데이터행 표와는 별개의 문제입니다.

# %% [markdown]
# #Artificial Intelligence
#
# ##Computer Vision
#
# **Object Detection*
#
# 1 Computer Vision
# 2 Natural Language Processing
# 3 Robotics
#
# |Model|Accuracy
# |YOLO|0.92
# |CNN|0.87

# %% [markdown]
# ## 10. 제출 전 확인
#
# - [ ] 파일명은 이름_학번_2주차.ipynb이다.
# - [ ] 주제 소개 3–5문장과 AI 처리 과정 4단계 이상을 작성했다.
# - [ ] 제목 3단계, 굵게·기울임·인라인 코드, 두 종류 목록을 확인했다.
# - [ ] 이미지 1개 이상과 설명 1–2문장이 있다.
# - [ ] 표는 3열 이상이며 데이터 행은 4개 이상이다.
# - [ ] 수식 2개 이상을 넣고 각각의 의미를 설명했다.
# - [ ] 관련 링크와 선택 이유/내용 설명이 있다.
# - [ ] 지정 코드를 실행하고 셀의 차이를 2가지 이상 설명했다.
# - [ ] Markdown 오류 수정 문제를 고쳤다.
# - [ ] 모든 셀을 위에서부터 확인했고, 모든 「✍ 직접 작성」 셀의 ⟪…⟫를 본인 내용으로 교체했다.
# - [ ] 수정한 내용이 Drive에 저장된 것을 확인했다.
#
# 현재 학기 과제 안내가 변경되면 최신 KLAS·조교 안내를 따릅니다. 제출본에서 스스로 설명할 수 없는 문장이나 수식이 남아 있지 않은지 마지막으로 읽어보세요.
#
# 입력 표시가 남아 있다면 아직 채우지 않은 작성란입니다. 안내 셀의 설명을 본인 답안으로 대신하지 않았는지 확인하세요.
